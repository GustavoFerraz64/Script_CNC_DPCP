# %%
import pandas as pd
import csv

df= pd.read_csv(r'C:\Users\NUNESFERRAZGUSTAVO\OneDrive - TK Elevator\Área de Trabalho\Script CNC Eduardo\teste.txt', 
                            encoding='latin-1', 
                            sep='\t', 
                            skiprows= 4, 
                            quoting=csv.QUOTE_NONE)

# %%
df
# Out:
#      Unnamed: 0         Dia  Unnamed: 2  Últ.iníc  Tipo  Unnamed: 5  \
# 0           NaN       Total         NaN       NaN   NaN         NaN
# 1           NaN  05.06.2024         NaN  05.06.24  ZPON         NaN
# 2           NaN  10.06.2024         NaN  10.06.24  ZPON         NaN
# 3           NaN  10.06.2024         NaN  10.06.24  ZPON         NaN
# 4           NaN  10.06.2024         NaN  10.06.24  ZPON         NaN
# ..          ...         ...         ...       ...   ...         ...
# 150         NaN  19.06.2024         NaN  19.06.24    LA         NaN
# 151         NaN  19.06.2024         NaN  19.06.24    LA         NaN
# 152         NaN  19.06.2024         NaN  19.06.24    LA         NaN
# 153         NaN  19.06.2024         NaN  19.06.24    LA         NaN
# 154         NaN  19.06.2024         NaN  19.06.24    LA         NaN
#
#        OrigNec.        Material  Unnamed: 8         Denominação  ...  Qtd.c  \
# ...

# %%
df.to_excel(r'C:\Users\NUNESFERRAZGUSTAVO\OneDrive - TK Elevator\Área de Trabalho\Script CNC Eduardo\teste.xlsx')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.to_excel(r'C:\Users\NUNESFERRAZGUSTAVO\OneDrive - TK Elevator\Área de Trabalho\Script CNC Eduardo\teste.xlsx')
#
# File c:\Users\NUNESFERRAZGUSTAVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
